# %% [markdown]
# Stemming:
# Stemming is the process of reducing words to their word stem, base, or root form.
# It involves removing suffixes or prefixes from words to derive their base form. Stemming algorithms are typically rule-based and can be fast and efficient. However, they may not always produce a valid root word. For example, the word "running"
# might be stemmed to "run", but "flies" might also be stemmed to "fli".
#
# Lemmatization:
# Lemmatization, on the other hand, aims to reduce words to their canonical form or lemma.
# Unlike stemming, lemmatization considers the context of the word and its part of speech (POS). It involves looking up words in a lexicon (such as WordNet) and applying morphological analysis to determine the lemma. Lemmatization ensures that the resulting word is a valid word in the language.
# For example, "ran" would be lemmatized to "run", and "better" would be lemmatized to "good".

# %%
# !pip install seaborn
# !pip install spacy
# !pip install python-docx
# !pip install docx2txt
# !python -m spacy download en_core_web_sm
# !pip install nltk
# Out:
# Requirement already satisfied: seaborn in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (3.7.4)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.7.0)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (63.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: python-docx in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-docx) (4.7.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: docx2txt in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.8)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.1/12.8 MB 544.7 kB/s eta 0:00:24
#       --------------------------------------- 0.2/12.8 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/12.8 MB 2.7 MB/s eta 0:00:05
#      --- ------------------------------------ 1.0/12.8 MB 4.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.4/12.8 MB 5.0 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.6/12.8 MB 5.2 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.6/12.8 MB 5.2 MB/s eta 0:00:03
#      ------- -------------------------------- 2.5/12.8 MB 6.0 MB/s eta 0:00:02
#      -------- ------------------------------- 2.8/12.8 MB 6.3 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 5.9 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.5/12.8 MB 6.2 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.8/12.8 MB 6.0 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 6.2 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 6.2 MB/s eta 0:00:02
#      ------------- -------------------------- 4.3/12.8 MB 5.6 MB/s eta 0:00:02
#      ------------- -------------------------- 4.4/12.8 MB 5.4 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 5.4 MB/s eta 0:00:02
#      --------------- ------------------------ 4.9/12.8 MB 5.5 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.3/12.8 MB 5.5 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/12.8 MB 5.6 MB/s eta 0:00:02
#      ------------------ --------------------- 6.0/12.8 MB 5.7 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 5.8 MB/s eta 0:00:02
#      -------------------- ------------------- 6.7/12.8 MB 6.0 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/12.8 MB 6.0 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.3/12.8 MB 5.9 MB/s eta 0:00:01
#      ------------------------ --------------- 7.7/12.8 MB 6.0 MB/s eta 0:00:01
#      ------------------------- -------------- 8.1/12.8 MB 6.2 MB/s eta 0:00:01
#      -------------------------- ------------- 8.5/12.8 MB 6.2 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.1/12.8 MB 6.2 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 6.2 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 6.3 MB/s eta 0:00:01
#      ------------------------------- -------- 10.1/12.8 MB 6.3 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 6.9 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/12.8 MB 6.8 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.2/12.8 MB 6.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 6.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 6.7 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 7.0 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 6.6 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.0)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (63.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np   
import pandas as pd    
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import spacy
from docx import Document
import warnings
import docx2txt

# %%
path = 'asgn1.docx'
text = docx2txt.process(path)
# path2 = 'testdoc2.docx'
# text2 = docx2txt.process(path2)

#  text is extracted from two Word documents using docx2txt.process()

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

# %%
sentences = list(doc.sents)
sentences[0]
# sentences variable contains a list of sentence tokens extracted from the first document (doc).
# Out:
# URL
#
# Purpose of Website
#
# Things liked
#
# Disliked
#
# Rating
#
# Click me
#
#
#
#
#
#
#
#
#
# Click me Now
#
# Typing Related
#
# -
#
# Not functioning/Live
#
# Bad
#
# Touch Here
#
# Sell automobile/Mopeds
#
# Crisp and short description
#
# TERRIBLE ui
#
# MEDIOCRE
#
# HERE
#
# Search engine
#
# Simple and responsive
#
# Cookies are checked each time
#
# Better
#
#
#
# END
#
# Social media site
#
# Simple design and usage
#
# Privacy concerns
#
# Good

# %%
for token in doc:
     print ("\n",token, token.idx, token.text_with_ws,
            token.is_alpha, token.is_punct, token.is_space,
            token.shape_, token.is_stop)
# This loop prints various attributes of each token in the first document, such as its text, index,
# Out:
#  URL 0 URL  True False False XXX False
#
#
#
#  4
#
#  False False True
#
#  False
#
#  Purpose 6 Purpose  True False False Xxxxx False
#
#  of 14 of  True False False xx True
#
#  Website 17 Website True False False Xxxxx False
#
#
#
#  24
#
#  False False True
#
#  False
#
#  Things 26 Things  True False False Xxxxx False
#
#  liked 33 liked True False False xxxx False
#
#
#
#  38
#
#  False False True
#
#  False
#
#  Disliked 40 Disliked True False False Xxxxx False
#
#
#
#  48
#
#  False False True
#
#  False
#
#  Rating 50 Rating True False False Xxxxx False
#
#
#
#  56
#
#  False False True
#
#  False
#
#  Click 58 Click  True False False Xxxxx False
#
#  me 64 me True False False xx True
#
#
#
#
#
#
#
#
#
#
#
#  66
#
#
#
#
#
#
#
#
#
#  False False True
#
#
#
#  False
#
#  Click 76 Click  True False False Xxxxx False
#
#  me 82 me  True False False xx True
#
#  Now 85 Now True False False Xxx True
#
#
#
#  88
#
#  False False True
#
#  False
#
#  Typing 90 Typing  True False False Xxxxx False
#
#  Related 97 Related True False False Xxxxx False
#
#
#
#  104
#
#  False False True
#
#  False
#
#  - 106 - False True False - False
#
#
#
#  107
#
#  False False True
#
#  False
#
#  Not 109 Not  True False False Xxx True
#
#  functioning 113 functioning True False False xxxx False
#
#  / 124 / False True False / False
#
#  Live 125 Live True False False Xxxx False
#
#
#
#  129
#
#  False False True
#
#  False
#
#  Bad 131 Bad True False False Xxx False
#
#
#
#  134
#
#  False False True
#
#  False
#
#  Touch 136 Touch  True False False Xxxxx False
#
#  Here 142 Here True False False Xxxx True
#
#
#
#  146
#
#  False False True
#
#  False
#
#  Sell 148 Sell  True False False Xxxx False
#
#  automobile 153 automobile True False False xxxx False
#
#  / 163 / False True False / False
#
#  Mopeds 164 Mopeds True False False Xxxxx False
#
#
#
#  170
#
#  False False True
#
#  False
#
#  Crisp 172 Crisp  True False False Xxxxx False
#
#  and 178 and  True False False xxx True
#
#  short 182 short  True False False xxxx False
#
#  description 188 description True False False xxxx False
#
#
#
#  199
#
#  False False True
#
#  False
#
#  TERRIBLE 201 TERRIBLE  True False False XXXX False
#
#  ui 210 ui True False False xx False
#
#
#
#  212
#
#  False False True
#
#  False
#
#  MEDIOCRE 214 MEDIOCRE True False False XXXX False
#
#
#
#  222
#
#  False False True
#
#  False
#
#  HERE 224 HERE True False False XXXX True
#
#
#
#  228
#
#  False False True
#
#  False
#
#  Search 230 Search  True False False Xxxxx False
#
#  engine 237 engine  True False False xxxx False
#
#
#
#  244
#
#  False False True
#
#  False
#
#  Simple 246 Simple  True False False Xxxxx False
#
#  and 253 and  True False False xxx True
#
#  responsive 257 responsive True False False xxxx False
#
#
#
#  267
#
#  False False True
#
#  False
#
#  Cookies 269 Cookies  True False False Xxxxx False
#
#  are 277 are  True False False xxx True
#
#  checked 281 checked  True False False xxxx False
#
#  each 289 each  True False False xxxx True
#
#  time 294 time True False False xxxx False
#
#
#
#  298
#
#  False False True
#
#  False
#
#  Better 300 Better True False False Xxxxx False
#
#
#
#
#
#  306
#
#
#
#  False False True
#
#
#
#  False
#
#  END 310 END True False False XXX False
#
#
#
#  313
#
#  False False True
#
#  False
#
#  Social 315 Social  True False False Xxxxx False
#
#  media 322 media  True False False xxxx False
#
#  site 328 site True False False xxxx False
#
#
#
#  332
#
#  False False True
#
#  False
#
#  Simple 334 Simple  True False False Xxxxx False
#
#  design 341 design  True False False xxxx False
#
#  and 348 and  True False False xxx True
#
#  usage 352 usage True False False xxxx False
#
#
#
#  357
#
#  False False True
#
#  False
#
#  Privacy 359 Privacy  True False False Xxxxx False
#
#  concerns 367 concerns True False False xxxx False
#
#
#
#  375
#
#  False False True
#
#  False
#
#  Good 377 Good True False False Xxxx False

# %%
stopwords = spacy.lang.en.stop_words.STOP_WORDS
# The stopwords variable contains a set of English stop words from SpaCy.

# %%
words = [word.lemma_ for word in doc]

# %%
for token in doc:
    print(token, token.pos_)
    # This loop prints each token along with its corresponding part-of-speech tag.
# Out:
# URL NOUN
#
#
#  SPACE
# Purpose PROPN
# of ADP
# Website PROPN
#
#
#  SPACE
# Things NOUN
# liked VERB
#
#
#  SPACE
# Disliked VERB
#
#
#  SPACE
# Rating NOUN
#
#
#  SPACE
# Click VERB
# me PRON
#
#
#
#
#
#
#
#
#
#
#  SPACE
# Click VERB
# me PRON
# Now ADV
#
#
#  SPACE
# Typing VERB
# Related VERB
#
#
#  SPACE
# - PUNCT
#
#
#  SPACE
# Not PART
# functioning VERB
# / SYM
# Live ADJ
#
#
#  SPACE
# Bad PROPN
#
#
#  SPACE
# Touch PROPN
# Here ADV
#
#
#  SPACE
# Sell NOUN
# automobile NOUN
# / SYM
# Mopeds NOUN
#
#
#  SPACE
# Crisp PROPN
# and CCONJ
# short ADJ
# description NOUN
#
#
#  SPACE
# TERRIBLE PROPN
# ui ADP
#
#
#  SPACE
# MEDIOCRE NOUN
#
#
#  SPACE
# HERE PROPN
#
#
#  SPACE
# Search NOUN
# engine NOUN
#
#
#  SPACE
# Simple ADJ
# and CCONJ
# responsive ADJ
#
#
#  SPACE
# Cookies NOUN
# are AUX
# checked VERB
# each DET
# time NOUN
#
#
#  SPACE
# Better ADJ
#
#
#
#
#  SPACE
# END PROPN
#
#
#  SPACE
# Social ADJ
# media NOUN
# site NOUN
#
#
#  SPACE
# Simple ADJ
# design NOUN
# and CCONJ
# usage NOUN
#
#
#  SPACE
# Privacy PROPN
# concerns NOUN
#
#
#  SPACE
# Good NOUN

# %%
verbs = [token.text for token in doc if token.pos_ == "VERB"]
nouns = [token.text for token in doc if token.pos_ == "NOUN"]

# %%
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer
nltk.download('wordnet')

ps = PorterStemmer()
stemmed = [ps.stem(token.text) for token in doc]

wl = WordNetLemmatizer()
wl_stem = [wl.lemmatize(token.text) for token in doc]
# NLTK's Porter Stemmer and WordNet Lemmatizer are used to 
# perform stemming and lemmatization on the words in the first document, respectively.
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# corpus = [text,text2]
corpus = [text]
def freq(corpus):
    dict = {}
    for doc in corpus:
        for word in doc.split():
            if word in dict:
                dict[word] += 1
            else:
                dict[word] = 1
    for word, fr in dict.items():
        print(word, fr)
        dict[word] = fr / len(doc)
    print('Document size in number of words', len(doc))
    return dict
freq(corpus)
# Out:
# URL 1
# Purpose 1
# of 1
# Website 1
# Things 1
# liked 1
# Disliked 1
# Rating 1
# Click 2
# me 2
# Now 1
# Typing 1
# Related 1
# - 1
# Not 1
# functioning/Live 1
# Bad 1
# Touch 1
# Here 1
# Sell 1
# automobile/Mopeds 1
# Crisp 1
# and 3
# short 1
# description 1
# TERRIBLE 1
# ui 1
# MEDIOCRE 1
# HERE 1
# Search 1
# engine 1
# Simple 2
# responsive 1
# Cookies 1
# are 1
# checked 1
# each 1
# time 1
# Better 1
# END 1
# Social 1
# media 1
# site 1
# design 1
# usage 1
# Privacy 1
# concerns 1
# Good 1
# Document size in number of words 381
# {'URL': 0.0026246719160104987,
#  'Purpose': 0.0026246719160104987,
#  'of': 0.0026246719160104987,
#  'Website': 0.0026246719160104987,
#  'Things': 0.0026246719160104987,
#  'liked': 0.0026246719160104987,
#  'Disliked': 0.0026246719160104987,
#  'Rating': 0.0026246719160104987,
#  'Click': 0.005249343832020997,
#  'me': 0.005249343832020997,
#  'Now': 0.0026246719160104987,
#  'Typing': 0.0026246719160104987,
#  'Related': 0.0026246719160104987,
#  '-': 0.0026246719160104987,
#  'Not': 0.0026246719160104987,
#  'functioning/Live': 0.0026246719160104987,
#  'Bad': 0.0026246719160104987,
#  'Touch': 0.0026246719160104987,
#  'Here': 0.0026246719160104987,
#  'Sell': 0.0026246719160104987,
#  'automobile/Mopeds': 0.0026246719160104987,
#  'Crisp': 0.0026246719160104987,
#  'and': 0.007874015748031496,
#  'short': 0.0026246719160104987,
#  'description': 0.0026246719160104987,
#  'TERRIBLE': 0.0026246719160104987,
#  'ui': 0.0026246719160104987,
#  'MEDIOCRE': 0.0026246719160104987,
#  'HERE': 0.0026246719160104987,
#  'Search': 0.0026246719160104987,
#  'engine': 0.0026246719160104987,
#  'Simple': 0.005249343832020997,
#  'responsive': 0.0026246719160104987,
#  'Cookies': 0.0026246719160104987,
#  'are': 0.0026246719160104987,
#  'checked': 0.0026246719160104987,
#  'each': 0.0026246719160104987,
#  'time': 0.0026246719160104987,
#  'Better': 0.0026246719160104987,
#  'END': 0.0026246719160104987,
#  'Social': 0.0026246719160104987,
#  'media': 0.0026246719160104987,
#  'site': 0.0026246719160104987,
#  'design': 0.0026246719160104987,
#  'usage': 0.0026246719160104987,
#  'Privacy': 0.0026246719160104987,
#  'concerns': 0.0026246719160104987,
#  'Good': 0.0026246719160104987}
